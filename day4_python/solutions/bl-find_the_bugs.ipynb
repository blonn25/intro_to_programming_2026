# %% [markdown]
# ## Find the Bugs!
# This notebook contains several bugs. Your task is to identify and fix them!

# %%
# Bug 1:
print("Hello everyone!") # This line should print a greeting, but there's something wrong here...
# Out:
# Hello everyone!

# %%
# Bug 2:
result = 10 + 5 * 2 # What should the result be? Is it what you expected?
print(result)
# Out:
# 20

# %%
# Bug 3:
message = "The value of the number is"
number = 25
print(message , number) # This should print both the message and the number, but it throws an error!
print(f"{message} {number}")
# Out:
# The value of the number is 25
# The value of the number is 25

# %%
# Bug 4:
word = "Programming"
print("The first letter is: ", word[0]) # This should print the first letter of the word.
# Out:
# The first letter is:  P

# %%
# Bug 5:
fruits = ["apple", "banana", "cherry"]
fruits.append("orange") # This should add 'orange' to the list.
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
# Bug 6:
temperature = 30
if temperature == 30:
    print("It's a warm day.")
elif temperature < 20:
    print("It's cold.")
else:
    print("The weather is nice.")
# Out:
# It's a warm day.

# %%
# Bug 7: Infinity!
counter = 0
while counter < 5:
    print(counter)
    counter += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Bug 8: File handling issue
with open('some_beloved_file.txt', 'w+') as file:
    content = file.read()
    print(content) # This doesn’t run

# %%
# Bug 9: Boolean logic error
x = 10
y = 20

if x > y or (x == 10 and y == 20): # Fix the logic so the condition makes sense.
    print("Condition is True")
else:
    print("Condition is False")
# Out:
# Condition is True

# %%
# Bug 9: Boolean logic error
x = 5
y = 3

if x > y or x == 10 and y == 20: # Fix the logic so the condition makes sense.
    print("Condition is True")
else:
    print("Condition is False")
# Out:
# Condition is True

# %%
# Bug 10: What a doozy...
nums = [1, 2, 3, 4, 5]
results = []

for num in nums:
    if num % 2 != 0:
        results.append(num)

print("Odd numbers are:", results)
# Out:
# Odd numbers are: [1, 3, 5]
